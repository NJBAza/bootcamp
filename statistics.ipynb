# %%
import numpy as np
from scipy import stats as st

# %%
pip list
# Out:
# Package           Version
# ----------------- -----------
# asttokens         2.0.5
# comm              0.2.1
# contourpy         1.3.0
# cycler            0.12.1
# debugpy           1.6.7
# decorator         5.1.1
# exceptiongroup    1.2.0
# executing         0.8.3
# fonttools         4.54.1
# ipykernel         6.29.5
# ipython           8.27.0
# jedi              0.19.1
# jupyter_client    8.6.0
# jupyter_core      5.7.2
# kiwisolver        1.4.7
# matplotlib        3.9.2
# matplotlib-inline 0.1.6
# nest-asyncio      1.6.0
# numpy             2.1.3
# packaging         24.1
# parso             0.8.3
# pexpect           4.8.0
# pillow            11.0.0
# pip               24.3.1
# platformdirs      3.10.0
# prompt-toolkit    3.0.43
# psutil            5.9.0
# ptyprocess        0.7.0
# pure-eval         0.2.2
# Pygments          2.15.1
# pyparsing         3.2.0
# python-dateutil   2.9.0.post0
# pyzmq             25.1.2
# scipy             1.14.1
# setuptools        75.3.0
# six               1.16.0
# stack-data        0.2.0
# tornado           6.4.1
# traitlets         5.14.3
# typing_extensions 4.11.0
# wcwidth           0.2.5
# wheel             0.44.0
# Note: you may need to restart the kernel to use updated packages.

# %%
data = [5, 10, 10, 9, 8]

# %%
mean = np.mean(data)
median = np.median(data)
std_dev = np.std(data)
mode = st.mode(data)[0]

# %%
print(st.mode(data))
print(st.mode(data)[0])
# Out:
# ModeResult(mode=np.int64(10), count=np.int64(2))
# 10

# %%
print(f"Media: {mean}, Mediana: {median}, Desviación estándar: {std_dev}, Moda: {mode}")
# Out:
# Media: 8.4, Mediana: 9.0, Desviación estándar: 1.8547236990991407, Moda: 10

# %%
import matplotlib.pyplot as plt

# %%
data_uni = np.random.normal(10,2,1000)

# %%
mean = np.mean(data_uni)
median = np.median(data_uni)
std_dev = np.std(data_uni)
mode = st.mode(data_uni)[0]

# %%
print(f"Media: {mean}, Mediana: {median}, Desviación estándar: {std_dev}, Moda: {mode}")
# Out:
# Media: 10.072896427673161, Mediana: 9.996656894014986, Desviación estándar: 2.0065429783198545, Moda: 4.416411024330233

# %%
plt.hist(data_uni, bins=30, label='Unimode')
# Out:
# (array([ 1.,  5.,  6.,  5., 20., 24., 30., 41., 54., 64., 74., 87., 85.,
#         81., 77., 61., 68., 56., 47., 38., 26., 18., 14.,  7.,  4.,  3.,
#          1.,  1.,  1.,  1.]),
#  array([ 4.41641102,  4.84455094,  5.27269086,  5.70083078,  6.1289707 ,
#          6.55711062,  6.98525054,  7.41339046,  7.84153038,  8.2696703 ,
#          8.69781022,  9.12595014,  9.55409006,  9.98222998, 10.4103699 ,
#         10.83850981, 11.26664973, 11.69478965, 12.12292957, 12.55106949,
#         12.97920941, 13.40734933, 13.83548925, 14.26362917, 14.69176909,
#         15.11990901, 15.54804893, 15.97618885, 16.40432877, 16.83246869,
#         17.26060861]),
#  <BarContainer object of 30 artists>)

# %%
data_bi = np.concatenate([np.random.normal(5,1,500), np.random.normal(15,1,500)])

# %%
plt.hist(data_bi, bins=30, label='Bimode')
# Out:
# (array([  2.,  10.,  22.,  44.,  89., 101., 106.,  65.,  38.,  18.,   3.,
#           1.,   1.,   0.,   0.,   0.,   0.,   0.,   0.,   4.,  14.,  42.,
#          75.,  89., 107.,  95.,  41.,  25.,   6.,   2.]),
#  array([ 1.82700404,  2.37178468,  2.91656533,  3.46134598,  4.00612662,
#          4.55090727,  5.09568791,  5.64046856,  6.18524921,  6.73002985,
#          7.2748105 ,  7.81959114,  8.36437179,  8.90915244,  9.45393308,
#          9.99871373, 10.54349438, 11.08827502, 11.63305567, 12.17783631,
#         12.72261696, 13.26739761, 13.81217825, 14.3569589 , 14.90173954,
#         15.44652019, 15.99130084, 16.53608148, 17.08086213, 17.62564278,
#         18.17042342]),
#  <BarContainer object of 30 artists>)

# %%
plt.hist(data_uni, bins=30, label='Unimode')
plt.hist(data_bi, bins=30, label='Bimode')
plt.legend()
plt.show();

# %%
random_data = np.random.randint(0,100,1000)

# %%
random_data
# Out:
# array([41,  5, 59, 50, 89, 13, 78, 87, 80, 15])

# %%
mean = np.mean(random_data)
median = np.median(random_data)
std_dev = np.std(random_data)
mode = st.mode(random_data)[0]

# %%
print(f"Media: {mean}, Mediana: {median}, Desviación estándar: {std_dev}, Moda: {mode}")
# Out:
# Media: 51.7, Mediana: 54.5, Desviación estándar: 30.538664017929793, Moda: 5

# %%
plt.hist(random_data, bins=100, label='Population')
plt.legend()
plt.show();

# %%
np.mean(random_data)
# Out:
# np.float64(51.7)

# %%
random_data
# Out:
# array([41,  5, 59, 50, 89, 13, 78, 87, 80, 15])

# %%
for _ in random_data:
    print(_)
# Out:
# 41
# 5
# 59
# 50
# 89
# 13
# 78
# 87
# 80
# 15

# %%
np.mean(np.random.randint(0,100,10))
# Out:
# np.float64(57.5)

# %%
sample_means = [np.mean(np.random.randint(0,100,100)) for _ in range(1000)]

# %%
plt.hist(sample_means, bins=30, density=True)
plt.title("Teorema del Límite Central")
plt.show()

# %% [markdown]
# # Operaciones Matriciales y Vectoriales

# %%
A = np.array([[1,2],[3,4]])
B = np.array([[2,0],[1,2]])

# %%
A
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
B
# Out:
# array([[2, 0],
#        [1, 2]])

# %%
print(np.dot(3,4))
# Out:
# 12

# %%
suma = A + B
producto = np.dot(A,B)

# %%
print(f'La suma de los vectores es: {suma}, y su producto punto es {producto}')
# Out:
# La suma de los vectores es: [[3 2]
#  [4 6]], y su producto punto es [[ 4  4]
#  [10  8]]

# %%
producto
# Out:
# array([[ 4,  4],
#        [10,  8]])

# %%
pip list
# Out:
# Package           Version
# ----------------- -----------
# asttokens         2.0.5
# comm              0.2.1
# contourpy         1.3.0
# cycler            0.12.1
# debugpy           1.6.7
# decorator         5.1.1
# exceptiongroup    1.2.0
# executing         0.8.3
# fonttools         4.54.1
# ipykernel         6.29.5
# ipython           8.27.0
# jedi              0.19.1
# jupyter_client    8.6.0
# jupyter_core      5.7.2
# kiwisolver        1.4.7
# matplotlib        3.9.2
# matplotlib-inline 0.1.6
# nest-asyncio      1.6.0
# numpy             2.1.3
# packaging         24.1
# parso             0.8.3
# pexpect           4.8.0
# pillow            11.0.0
# pip               24.3.1
# platformdirs      3.10.0
# prompt-toolkit    3.0.43
# psutil            5.9.0
# ptyprocess        0.7.0
# pure-eval         0.2.2
# Pygments          2.15.1
# pyparsing         3.2.0
# python-dateutil   2.9.0.post0
# pyzmq             25.1.2
# scipy             1.14.1
# setuptools        75.3.0
# six               1.16.0
# stack-data        0.2.0
# tornado           6.4.1
# traitlets         5.14.3
# typing_extensions 4.11.0
# wcwidth           0.2.5
# wheel             0.44.0
# Note: you may need to restart the kernel to use updated packages.
